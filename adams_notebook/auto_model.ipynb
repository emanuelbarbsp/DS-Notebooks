# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# !pip install islp
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)
# Out:
# ...
#   Using cached lifelines-0.28.0-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached pygam-0.9.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached torchmetrics-1.4.0.post0-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached autograd-1.6.2-py3-none-any.whl.metadata (706 bytes)
# ...
#   Using cached autograd_gamma-0.5.0-py3-none-any.whl
# ...
#   Using cached formulaic-1.0.1-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached progressbar2-4.4.2-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached lightning_utilities-0.11.2-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# ...
#   Using cached interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# ...
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.2 kB)
# ...
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# ...
#   Using cached python_utils-3.8.2-py2.py3-none-any.whl.metadata (9.7 kB)
# ...

# %%
Auto = pd.read_csv(r"Downloads\Auto.csv")
print(autodata.to_string())
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  origin                                  name
# 0    18.0          8         307.0        130    3504          12.0    70       1             chevrolet chevelle malibu
# 1    15.0          8         350.0        165    3693          11.5    70       1                     buick skylark 320
# 2    18.0          8         318.0        150    3436          11.0    70       1                    plymouth satellite
# 3    16.0          8         304.0        150    3433          12.0    70       1                         amc rebel sst
# 4    17.0          8         302.0        140    3449          10.5    70       1                           ford torino
# 5    15.0          8         429.0        198    4341          10.0    70       1                      ford galaxie 500
# 6    14.0          8         454.0        220    4354           9.0    70       1                      chevrolet impala
# ...

# %%
X = MS(['cylinders', 'origin']).fit_transform(Auto)
model1 = sm.OLS(y, X)
results1 = model1.fit()
summarize(results1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 X = MS(['cylinders', 'origin']).fit_transform(Auto)
# ----> 2 model1 = sm.OLS(y, X)
#       3 results1 = model1.fit()
#       4 summarize(results1)
#
# NameError: name 'sm' is not defined
